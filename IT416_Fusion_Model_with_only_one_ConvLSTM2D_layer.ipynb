# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import cv2
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from IPython.display import display
from keras.utils.vis_utils import plot_model

# %%
if not os.path.isfile('processed_dataset.zip'):
  os.system(' '.join(['cp', 'drive/MyDrive/IT416/processed_dataset.zip', 'processed_dataset.zip']))

# %%
if not os.path.isdir('processed_dataset'):
  os.system(' '.join(['unzip', 'processed_dataset.zip']))

# %%
def get_dataset(num_people):
  x1 = []
  x2 = []
  y  = []
  for i in range(num_people):
      for j in range(10):
          path = 'processed_dataset' + '/' + 'person' + str(i+1) + '/' + 'face' + '/' + str(j+1) + '.pgm'
          image = cv2.imread(path, -1)
          image = cv2.resize(image, (12, 12))
          image = image.reshape(12, 12, 1)
          x1.append(image)
      gait_folder = 'processed_dataset' + '/' + 'person' + str(i+1) + '/' + 'gait' + '/'
      styles = os.listdir(gait_folder)
      styles.sort()
      for j, style in enumerate(styles):
          style_folder = gait_folder + style + '/'
          angles = os.listdir(style_folder)
          angles.sort()
          x = []
          for angle in angles:
              angle_folder = style_folder + angle + '/'
              images = os.listdir(angle_folder)
              images.sort()
              random.shuffle(images)
              images = images[: 16]
              images.sort()
              xx = []
              for image in images:
                  path = angle_folder + image
                  img = cv2.imread(path, -1)
                  img = cv2.resize(img, (32, 32))
                  img = np.array(img, dtype=np.float16)
                  xx.append(img)
              xx = np.array(xx, dtype=np.float16)
              x.append(xx)
          x = np.stack(x, axis=3)
          x2.append(x)
      for j in range(10):
          y.append(i)
  x1 = np.array(x1, dtype = np.float32)
  x2 = np.array(x2, dtype = np.float32)
  y = tf.keras.utils.to_categorical(y)
  x1, x2, y = shuffle(x1, x2, y)
  return x1, x2, y

# %%
num_people = 40
x_face, x_gait, y = get_dataset(num_people)

print('x_face:', x_face.shape)
print('x_gait:', x_gait.shape)
print('y     :', y.shape)
# Out:
# x_face: (400, 12, 12, 1)
# x_gait: (400, 16, 32, 32, 11)
# y     : (400, 40)

# %%
face_input = tf.keras.layers.Input(shape = (12, 12, 1), name = 'face_input')

face_encoder = tf.keras.layers.Conv2D(32, kernel_size = 3, activation = 'relu', name = 'face_conv_1')(face_input)
face_encoder = tf.keras.layers.Dropout(0.2, name = 'face_dropout_1')(face_encoder)
face_encoder = tf.keras.layers.Flatten(name = 'face_flatten_1')(face_encoder)
face_encoder = tf.keras.layers.Dense(64, activation = 'relu', name = 'face_dense_1')(face_encoder)
face_encoder = tf.keras.layers.Dropout(0.2, name = 'face_dropout_2')(face_encoder)
face_encoder = tf.keras.layers.BatchNormalization()(face_encoder)

gait_input = tf.keras.layers.Input(shape = (16, 32, 32, 11), name = 'gait_input')

gait_encoder = tf.keras.layers.ConvLSTM2D(16, kernel_size = 3, name = 'gait_convlstm_1')(gait_input)
gait_encoder = tf.keras.layers.Dropout(0.4, name = 'gait_dropout_1')(gait_encoder)
gait_encoder = tf.keras.layers.Flatten(name = 'gait_flatten_1')(gait_encoder)
gait_encoder = tf.keras.layers.Dense(64, activation = 'relu', name = 'gait_dense_1')(gait_encoder)
gait_encoder = tf.keras.layers.Dropout(0.4, name = 'gait_dropout_4')(gait_encoder)
gait_encoder = tf.keras.layers.BatchNormalization()(gait_encoder)

def weighted_average(tensors):
  alpha = 0.5
  face = tensors[0]
  gait = tensors[1]
  weighted_average = alpha * face + (1 - alpha) * gait
  return weighted_average

decoder = tf.keras.layers.Lambda(weighted_average, name = 'face_gait_weighted_average')([face_encoder, gait_encoder])

decoder = tf.keras.layers.Dense(40, activation = 'softmax', name = 'output')(decoder)

model = tf.keras.models.Model(
      inputs = [face_input, gait_input], 
      outputs = decoder)

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0003), 
              loss = 'categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  face_input (InputLayer)        [(None, 12, 12, 1)]  0           []
#
#  gait_input (InputLayer)        [(None, 16, 32, 32,  0           []
#                                  11)]
#
#  face_conv_1 (Conv2D)           (None, 10, 10, 32)   320         ['face_input[0][0]']
#
#  gait_convlstm_1 (ConvLSTM2D)   (None, 30, 30, 16)   15616       ['gait_input[0][0]']
#
#  face_dropout_1 (Dropout)       (None, 10, 10, 32)   0           ['face_conv_1[0][0]']
#
#  gait_dropout_1 (Dropout)       (None, 30, 30, 16)   0           ['gait_convlstm_1[0][0]']
#
#  face_flatten_1 (Flatten)       (None, 3200)         0           ['face_dropout_1[0][0]']
#
#  gait_flatten_1 (Flatten)       (None, 14400)        0           ['gait_dropout_1[0][0]']
#
#  face_dense_1 (Dense)           (None, 64)           204864      ['face_flatten_1[0][0]']
#
#  gait_dense_1 (Dense)           (None, 64)           921664      ['gait_flatten_1[0][0]']
#
#  face_dropout_2 (Dropout)       (None, 64)           0           ['face_dense_1[0][0]']
#
#  gait_dropout_4 (Dropout)       (None, 64)           0           ['gait_dense_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64)          256         ['face_dropout_2[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 64)          256         ['gait_dropout_4[0][0]']
#  rmalization)
#
#  face_gait_weighted_average (La  (None, 64)          0           ['batch_normalization[0][0]',
#  mbda)                                                            'batch_normalization_1[0][0]']
#
#  output (Dense)                 (None, 40)           2600        ['face_gait_weighted_average[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 1,145,576
# Trainable params: 1,145,320
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
plot = plot_model(model, show_shapes = True, to_file = 'model.png', show_layer_names = True)
display(plot)

# %%
EPOCHS = 60
BATCH_SIZE = 4
VALID_SPLIT = 0.3

acc_train = []
acc_val = []

# %%
history = model.fit([x_face, x_gait], y, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_split = VALID_SPLIT)
acc_train += history.history['accuracy']
acc_val += history.history['val_accuracy']
# Out:
# Epoch 1/60
# 70/70 [==============================] - 20s 111ms/step - loss: 3.7461 - accuracy: 0.0321 - val_loss: 3.8650 - val_accuracy: 0.0250
# Epoch 2/60
# 70/70 [==============================] - 8s 111ms/step - loss: 3.4524 - accuracy: 0.0857 - val_loss: 3.5586 - val_accuracy: 0.0750
# Epoch 3/60
# 70/70 [==============================] - 7s 101ms/step - loss: 3.3140 - accuracy: 0.1643 - val_loss: 3.4573 - val_accuracy: 0.1583
# Epoch 4/60
# 70/70 [==============================] - 7s 101ms/step - loss: 3.1688 - accuracy: 0.2429 - val_loss: 3.4288 - val_accuracy: 0.1583
# Epoch 5/60
# 70/70 [==============================] - 7s 101ms/step - loss: 3.0433 - accuracy: 0.2821 - val_loss: 3.2290 - val_accuracy: 0.2250
# Epoch 6/60
# 70/70 [==============================] - 8s 109ms/step - loss: 2.9015 - accuracy: 0.3357 - val_loss: 3.2410 - val_accuracy: 0.1083
# Epoch 7/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.8357 - accuracy: 0.3821 - val_loss: 3.2481 - val_accuracy: 0.2167
# Epoch 8/60
# 70/70 [==============================] - 8s 110ms/step - loss: 2.7697 - accuracy: 0.4643 - val_loss: 3.1569 - val_accuracy: 0.3000
# Epoch 9/60
# 70/70 [==============================] - 8s 111ms/step - loss: 2.6650 - accuracy: 0.5321 - val_loss: 3.2499 - val_accuracy: 0.1750
# Epoch 10/60
# 70/70 [==============================] - 8s 110ms/step - loss: 2.6030 - accuracy: 0.5643 - val_loss: 3.1519 - val_accuracy: 0.2417
# Epoch 11/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.6243 - accuracy: 0.5071 - val_loss: 3.1257 - val_accuracy: 0.2667
# Epoch 12/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.4956 - accuracy: 0.5714 - val_loss: 3.0609 - val_accuracy: 0.3167
# Epoch 13/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.3866 - accuracy: 0.6536 - val_loss: 3.2087 - val_accuracy: 0.1917
# Epoch 14/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.3394 - accuracy: 0.6571 - val_loss: 3.0787 - val_accuracy: 0.2083
# Epoch 15/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.3216 - accuracy: 0.6750 - val_loss: 3.1995 - val_accuracy: 0.1500
# Epoch 16/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.2439 - accuracy: 0.7000 - val_loss: 3.0059 - val_accuracy: 0.4083
# Epoch 17/60
# 70/70 [==============================] - 7s 102ms/step - loss: 2.2708 - accuracy: 0.6750 - val_loss: 2.9701 - val_accuracy: 0.3750
# Epoch 18/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.1504 - accuracy: 0.7286 - val_loss: 2.9042 - val_accuracy: 0.4333
# Epoch 19/60
# 70/70 [==============================] - 7s 101ms/step - loss: 2.1186 - accuracy: 0.7107 - val_loss: 2.9399 - val_accuracy: 0.4333
# Epoch 20/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.9901 - accuracy: 0.8214 - val_loss: 3.0436 - val_accuracy: 0.3000
# Epoch 21/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.9838 - accuracy: 0.7429 - val_loss: 2.8887 - val_accuracy: 0.2750
# Epoch 22/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.9763 - accuracy: 0.7500 - val_loss: 3.1468 - val_accuracy: 0.2417
# Epoch 23/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.8411 - accuracy: 0.7679 - val_loss: 2.9632 - val_accuracy: 0.2833
# Epoch 24/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.8443 - accuracy: 0.7929 - val_loss: 2.7522 - val_accuracy: 0.4833
# Epoch 25/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.7585 - accuracy: 0.8179 - val_loss: 2.7708 - val_accuracy: 0.3500
# Epoch 26/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.5770 - accuracy: 0.8286 - val_loss: 2.8418 - val_accuracy: 0.3417
# Epoch 27/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.6254 - accuracy: 0.8679 - val_loss: 2.6889 - val_accuracy: 0.4667
# Epoch 28/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.5812 - accuracy: 0.8643 - val_loss: 2.6732 - val_accuracy: 0.4667
# Epoch 29/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.5781 - accuracy: 0.8536 - val_loss: 2.5006 - val_accuracy: 0.5833
# Epoch 30/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.4743 - accuracy: 0.8643 - val_loss: 2.4852 - val_accuracy: 0.5250
# Epoch 31/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.4362 - accuracy: 0.8286 - val_loss: 2.5673 - val_accuracy: 0.3917
# Epoch 32/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.3750 - accuracy: 0.8679 - val_loss: 2.3836 - val_accuracy: 0.5667
# Epoch 33/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.3592 - accuracy: 0.8500 - val_loss: 2.4944 - val_accuracy: 0.4083
# Epoch 34/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.2278 - accuracy: 0.9036 - val_loss: 2.4500 - val_accuracy: 0.5000
# Epoch 35/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.2482 - accuracy: 0.9071 - val_loss: 2.3622 - val_accuracy: 0.5500
# Epoch 36/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.1566 - accuracy: 0.8929 - val_loss: 2.3180 - val_accuracy: 0.5333
# Epoch 37/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.1222 - accuracy: 0.9071 - val_loss: 2.4538 - val_accuracy: 0.4000
# Epoch 38/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.1274 - accuracy: 0.8857 - val_loss: 2.3187 - val_accuracy: 0.5333
# Epoch 39/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.0406 - accuracy: 0.9250 - val_loss: 2.1971 - val_accuracy: 0.6000
# Epoch 40/60
# 70/70 [==============================] - 8s 110ms/step - loss: 1.0566 - accuracy: 0.8929 - val_loss: 2.2619 - val_accuracy: 0.5500
# Epoch 41/60
# 70/70 [==============================] - 7s 101ms/step - loss: 1.0086 - accuracy: 0.9179 - val_loss: 2.1157 - val_accuracy: 0.6083
# Epoch 42/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.9115 - accuracy: 0.9250 - val_loss: 2.2549 - val_accuracy: 0.4833
# Epoch 43/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.8277 - accuracy: 0.9500 - val_loss: 2.0827 - val_accuracy: 0.7000
# Epoch 44/60
# 70/70 [==============================] - 8s 111ms/step - loss: 0.9056 - accuracy: 0.9214 - val_loss: 2.0662 - val_accuracy: 0.6333
# Epoch 45/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.8074 - accuracy: 0.9321 - val_loss: 2.0827 - val_accuracy: 0.6250
# Epoch 46/60
# 70/70 [==============================] - 7s 102ms/step - loss: 0.7281 - accuracy: 0.9500 - val_loss: 1.9520 - val_accuracy: 0.6583
# Epoch 47/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.8165 - accuracy: 0.9214 - val_loss: 2.0835 - val_accuracy: 0.6500
# Epoch 48/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.7223 - accuracy: 0.9571 - val_loss: 2.0062 - val_accuracy: 0.6083
# Epoch 49/60
# 70/70 [==============================] - 8s 110ms/step - loss: 0.7498 - accuracy: 0.9464 - val_loss: 1.9550 - val_accuracy: 0.7000
# Epoch 50/60
# 70/70 [==============================] - 8s 110ms/step - loss: 0.6875 - accuracy: 0.9500 - val_loss: 2.2106 - val_accuracy: 0.4750
# Epoch 51/60
# 70/70 [==============================] - 8s 111ms/step - loss: 0.6821 - accuracy: 0.9571 - val_loss: 2.1471 - val_accuracy: 0.5167
# Epoch 52/60
# 70/70 [==============================] - 8s 110ms/step - loss: 0.6340 - accuracy: 0.9643 - val_loss: 2.1085 - val_accuracy: 0.5250
# Epoch 53/60
# 70/70 [==============================] - 7s 102ms/step - loss: 0.6118 - accuracy: 0.9607 - val_loss: 1.9311 - val_accuracy: 0.5667
# Epoch 54/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.6265 - accuracy: 0.9679 - val_loss: 1.9018 - val_accuracy: 0.6333
# Epoch 55/60
# 70/70 [==============================] - 8s 110ms/step - loss: 0.6132 - accuracy: 0.9607 - val_loss: 1.8960 - val_accuracy: 0.6583
# Epoch 56/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.6170 - accuracy: 0.9571 - val_loss: 2.1735 - val_accuracy: 0.4500
# Epoch 57/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.5412 - accuracy: 0.9571 - val_loss: 2.0940 - val_accuracy: 0.5500
# Epoch 58/60
# 70/70 [==============================] - 7s 101ms/step - loss: 0.5022 - accuracy: 0.9786 - val_loss: 2.0813 - val_accuracy: 0.5000
# Epoch 59/60
# 70/70 [==============================] - 7s 102ms/step - loss: 0.5057 - accuracy: 0.9714 - val_loss: 1.8236 - val_accuracy: 0.6667
# Epoch 60/60
# 70/70 [==============================] - 8s 111ms/step - loss: 0.4632 - accuracy: 0.9714 - val_loss: 1.7517 - val_accuracy: 0.6750

# %%
history = model.fit([x_face, x_gait], y, batch_size = BATCH_SIZE, epochs = 10, validation_split = VALID_SPLIT)
acc_train += history.history['accuracy']
acc_val += history.history['val_accuracy']
# Out:
# Epoch 1/10
# 70/70 [==============================] - 7s 103ms/step - loss: 0.5001 - accuracy: 0.9679 - val_loss: 1.7578 - val_accuracy: 0.6583
# Epoch 2/10
# 70/70 [==============================] - 7s 101ms/step - loss: 0.5070 - accuracy: 0.9571 - val_loss: 1.6130 - val_accuracy: 0.6833
# Epoch 3/10
# 70/70 [==============================] - 7s 101ms/step - loss: 0.4844 - accuracy: 0.9464 - val_loss: 1.6543 - val_accuracy: 0.6583
# Epoch 4/10
# 70/70 [==============================] - 8s 110ms/step - loss: 0.3811 - accuracy: 0.9893 - val_loss: 1.6775 - val_accuracy: 0.6250
# Epoch 5/10
# 70/70 [==============================] - 7s 101ms/step - loss: 0.3837 - accuracy: 0.9786 - val_loss: 1.6320 - val_accuracy: 0.6667
# Epoch 6/10
# 70/70 [==============================] - 7s 102ms/step - loss: 0.3775 - accuracy: 0.9857 - val_loss: 1.5574 - val_accuracy: 0.7000
# Epoch 7/10
# 70/70 [==============================] - 7s 101ms/step - loss: 0.3650 - accuracy: 0.9786 - val_loss: 1.6739 - val_accuracy: 0.6333
# Epoch 8/10
# 70/70 [==============================] - 8s 110ms/step - loss: 0.4222 - accuracy: 0.9679 - val_loss: 1.7719 - val_accuracy: 0.6000
# Epoch 9/10
# 70/70 [==============================] - 8s 110ms/step - loss: 0.4812 - accuracy: 0.9679 - val_loss: 1.7643 - val_accuracy: 0.6167
# Epoch 10/10
# 70/70 [==============================] - 7s 101ms/step - loss: 0.4759 - accuracy: 0.9429 - val_loss: 1.7544 - val_accuracy: 0.6167

# %%
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 18

plt.plot(acc_train, linewidth=2)
plt.plot(acc_val, linewidth=2)
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.grid()

plt.show()
